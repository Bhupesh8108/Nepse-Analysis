# %%
import pandas as pd
data = pd.read_excel('/home/kali/Desktop/74.xlsx')
data.drop_duplicates(inplace=True,keep=False)
data2 = pd.read_excel('/home/kali/Desktop/170071842078 to 84 (L-4 cash) final.pdf.xlsx')
data2.drop_duplicates(inplace=True,keep=False)
data2.dropna(how = 'any', axis = 0, inplace=True)
admin_data,cash_data = data,data2
cash_data.columns = admin_data.columns
pokhara_data = cash_data[cash_data['Roll No'] >= 810001] 
pokhara_data = pokhara_data[pokhara_data['Roll No'] <= 811772]

# %%
import plotly.express as pe
from plotly.subplots import  make_subplots
pe.pie(values=admin_data.gender.value_counts().values,names=['Female','Male','Other'],title='Admin Exam')

# %%
pe.pie(values=pokhara_data.gender.value_counts().values,names=['Female','Male'],title='Cash exam')

# %%
admin_data.criteria.value_counts()
# Out:
# खुरा, भहहरा                  2092
# खुरा                         1086
# खुरा, भहहरा, आ/ज              413
# खुरा, आ/ज                     183
# खुरा, भहहरा, दशरत             126
# खुरा, भधेर्ी                   89
# खुरा, दशरत                     65
# भहहरा                          37
# खुरा, भहहरा, भधेर्ी            36
# भहहरा, आ/ज                     14
# दशरत                            6
# आ/ज                             4
# भहहरा, दशरत                     4
# खुरा, भधेर्ी, दशरत              4
# भधेर्ी                          2
# खुरा, भहहरा, भधेर्ी, दशरत       1
# भहहरा, भधेर्ी                   1
# खुरा, भहहरा, आ/ज, भधेर्ी        1
# Name: criteria, dtype: int64

# %%
pokhara_data.criteria.value_counts()
# Out:
# खला, मिहला                 964
# खला                        517
# खला, मिहला, आ/ज            163
# खला, आ/ज                    73
# खला, अपा                    17
# मिहला                       10
# खला, मिहला, अपा             10
# मिहला, आ/ज                   6
# आ/ज                          4
# खला, आ/ज, अपा                4
# खला, मिहला, आ/ज, अपा         2
# अपा                          2
# Name: criteria, dtype: int64

# %%
data3 = pd.read_excel('/home/kali/Desktop/169959328759 to 62 (L-5).xlsx')
data3.drop_duplicates(inplace=True,keep=False)
data3.dropna(how = 'any', axis = 0, inplace=True)

# %%
print(data3['Unnamed: 0'].isin(pokhara_data['User ID']).value_counts())
len(set(pokhara_data['User ID']).intersection (set(admin_data['User ID'])).intersection(set(data3['Unnamed: 0'])))
# Out:
# False    5666
# True      618
# Name: Unnamed: 0, dtype: int64
# 593

# %%
common_user = set(pokhara_data['User ID']).intersection (set(admin_data['User ID']))

# %%
common_user_data = data[data['User ID'].isin(common_user)]
pe.pie(values=common_user_data.gender.value_counts().values, names=['Female', 'Male'], title='Student appered in both exam')
